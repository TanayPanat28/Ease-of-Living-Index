# %%
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import scipy.stats as stats
from factor_analyzer.factor_analyzer import calculate_kmo

# %%
economic_data = pd.read_csv("Economic_data.csv")

# %%
import pandas as pd 
import miceforest as mf
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Economic_data.csv")

data_for_imputation = data.drop(['Country', 'Year'], axis=1)

kernel = mf.ImputationKernel(
    data_for_imputation,
    num_datasets = 1,
    mean_match_candidates=0,
    random_state = 28
    )

kernel.mice(30)
imputed_data = kernel.complete_data(0)

imputed_data['Country'] = data['Country']
imputed_data['Year'] = data['Year']

imputed_data.to_csv('imputed_economic_data_mice.csv', index=False)

df = pd.read_csv("imputed_economic_data_mice.csv")

# %%
kernel.plot_feature_importance(dataset=0)

# %%
kernel.plot_imputed_distributions()

# %%
optimal_params = kernel.tune_parameters(
    dataset=0, 
    use_gbdt=True,
    num_iterations=500,
    random_state=1,
)
kernel.mice(1, variable_parameters=optimal_params)
pd.DataFrame(optimal_params)
# Out:
#                         Cost of Living Index Local Purchasing Power Index  \
# boosting                                gbdt                         gbdt
# data_sample_strategy                 bagging                      bagging
# num_iterations                           498                          500
# max_depth                                  4                            4
# num_leaves                                12                           17
# min_data_in_leaf                           3                            5
# min_sum_hessian_in_leaf                 0.01                         0.01
# min_gain_to_split                        0.0                          0.0
# bagging_fraction                    0.580973                     0.501521
# feature_fraction_bynode             0.922566                     0.299912
# bagging_freq                               1                            1
# verbosity                                 -1                           -1
# learning_rate                           0.02                         0.02
# objective                         regression                   regression
#
#                         Unemployment_Rate Inflation_Rate GDP_Per_Capita  \
# boosting                             gbdt           gbdt           gbdt
# data_sample_strategy              bagging        bagging        bagging
# num_iterations                        500            209            500
# max_depth                               4              4              4
# num_leaves                             24             22              5
# min_data_in_leaf                        6             15              1
# min_sum_hessian_in_leaf              0.01           0.01           0.01
# min_gain_to_split                     0.0            0.0            0.0
# bagging_fraction                 0.307914       0.917682       0.209209
# feature_fraction_bynode          0.580104       0.661024       0.140097
# bagging_freq                            1              1              1
# verbosity                              -1             -1             -1
# learning_rate                        0.02           0.02           0.02
# objective                      regression     regression     regression
#
#                         GDP_Growth_Rate
# boosting                           gbdt
# data_sample_strategy            bagging
# num_iterations                      500
# max_depth                             4
# num_leaves                           15
# min_data_in_leaf                     11
# min_sum_hessian_in_leaf            0.01
# min_gain_to_split                   0.0
# bagging_fraction               0.989755
# feature_fraction_bynode        0.621771
# bagging_freq                          1
# verbosity                            -1
# learning_rate                      0.02
# objective                    regression

# %%
kernel.mice(30,variable_parameters=optimal_params)
imputed_data = kernel.complete_data(0)

imputed_data['Country'] = data['Country']
imputed_data['Year'] = data['Year']

imputed_data.to_csv('Testing_imputation.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

original_data = pd.read_csv("Economic_data.csv")

original_data_clean = original_data.drop(['Country', 'Year'], axis=1)
imputed_data_clean = imputed_data.drop(['Country', 'Year'], axis=1)

def plot_distributions(original, imputed, column_name):
    plt.figure(figsize=(10, 6))

    sns.kdeplot(original.dropna(), label="Original (Non-Missing)", color='blue', shade=True)
    missing_indices = original[original.isna()].index
    sns.kdeplot(imputed.loc[missing_indices], label="Imputed", color='red', shade=True)
    
    plt.title(f'Distributional Comparison: {column_name}')
    plt.legend()
    plt.show()


for column in original_data_clean.columns:
    plot_distributions(original_data_clean[column], imputed_data_clean[column], column)
# Out:
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\267355917.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.

# %%
variance_all_columns = original_data_clean.var()
print(variance_all_columns)
# Out:
# GDP_Growth_Rate                 4.059713e+01
# Inflation_Rate                  9.066202e+04
# GDP_Per_Capita                  2.899678e+08
# Unemployment_Rate               2.957196e+01
# Cost of Living Index            5.252450e+02
# Local Purchasing Power Index    1.023446e+03
# dtype: float64

# %%
variance_imputed_data = imputed_data_clean.var()
print(variance_imputed_data)
# Out:
# GDP_Growth_Rate                 4.143026e+01
# Inflation_Rate                  1.570603e+05
# GDP_Per_Capita                  3.274414e+08
# Unemployment_Rate               2.532982e+01
# Cost of Living Index            2.660989e+02
# Local Purchasing Power Index    4.999176e+02
# dtype: float64

# %%
print("Missing values in the original data:")
print(original_data.isna().sum())

print("\nMissing values in the imputed data:")
print(imputed_data.isna().sum())
# Out:
# Missing values in the original data:
# Country                             0
# Year                                0
# GDP_Growth_Rate                   362
# Inflation_Rate                   2802
# GDP_Per_Capita                    616
# Unemployment_Rate                5299
# Cost of Living Index            11241
# Local Purchasing Power Index    11241
# dtype: int64
#
# Missing values in the imputed data:
# GDP_Growth_Rate                 0
# Inflation_Rate                  0
# GDP_Per_Capita                  0
# Unemployment_Rate               0
# Cost of Living Index            0
# Local Purchasing Power Index    0
# Country                         0
# Year                            0
# dtype: int64

# %%
df = pd.read_csv("Testing_imputation.csv")

df= df.interpolate(method='linear', limit_direction='forward', axis=0)

df_numeric = df.drop(columns=['Country', 'Year'])

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_numeric)

kmo_all,kmo_model=calculate_kmo(df_scaled)
kmo_model
# Out:
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_6876\1463223658.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
# 0.7172177840127636
