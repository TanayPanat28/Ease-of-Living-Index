# %%
import pandas as pd 
import miceforest as mf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Quality_of_Life_final.csv")

data.columns = data.columns.str.replace(' ', '_').str.replace(r'[^a-zA-Z0-9_]', '', regex=True)

data_for_imputation = data.drop(['Country', 'Year'], axis=1)

kernel = mf.ImputationKernel(
    data_for_imputation,
    num_datasets = 1,
    mean_match_candidates=0,
    random_state = 28
    )

kernel.mice(30)
imputed_data = kernel.complete_data(0)

imputed_data['Country'] = data['Country']
imputed_data['Year'] = data['Year']

imputed_data.to_csv("Testing.csv", index=False)

# %%
kernel.plot_feature_importance(dataset=0)

# %%
kernel.plot_imputed_distributions()

# %%
optimal_params = kernel.tune_parameters(
    dataset=0, 
    use_gbdt=True,
    num_iterations=500,
    random_state=1,
)
kernel.mice(1, variable_parameters=optimal_params)
pd.DataFrame(optimal_params)
# Out:
#                         Health_Care_Index Crime_Index Doctors_Per_10000  \
# boosting                             gbdt        gbdt              gbdt
# data_sample_strategy              bagging     bagging           bagging
# num_iterations                        500         500               500
# max_depth                               5           4                 4
# num_leaves                             23          17                24
# min_data_in_leaf                        1           5                 5
# min_sum_hessian_in_leaf              0.01        0.01              0.01
# min_gain_to_split                     0.0         0.0               0.0
# bagging_fraction                 0.999136    0.501521          0.307914
# feature_fraction_bynode           0.31248    0.299912          0.580104
# bagging_freq                            1           1                 1
# verbosity                              -1          -1                -1
# learning_rate                        0.02        0.02              0.02
# objective                      regression  regression        regression
#
#                         Gender_Inequality_Index Gender_Development_Index  \
# boosting                                   gbdt                     gbdt
# data_sample_strategy                    bagging                  bagging
# num_iterations                              500                      500
# max_depth                                     5                        3
# num_leaves                                   18                       18
# min_data_in_leaf                              1                       68
# min_sum_hessian_in_leaf                    0.01                     0.01
# min_gain_to_split                           0.0                      0.0
# bagging_fraction                       0.779917                 0.484219
# feature_fraction_bynode                0.778489                 0.776686
# bagging_freq                                  1                        1
# verbosity                                    -1                       -1
# learning_rate                              0.02                     0.02
# objective                            regression               regression
#
#                         Human_Development_Index  \
# boosting                                   gbdt
# data_sample_strategy                    bagging
# num_iterations                              500
# max_depth                                     4
# num_leaves                                   15
# min_data_in_leaf                              9
# min_sum_hessian_in_leaf                    0.01
# min_gain_to_split                           0.0
# bagging_fraction                       0.989755
# feature_fraction_bynode                0.621771
# bagging_freq                                  1
# verbosity                                    -1
# learning_rate                              0.02
# objective                            regression
#
#                         Carbon_dioxide_emissions_per_capita_production_tonnes  \
# boosting                                                              gbdt
# data_sample_strategy                                               bagging
# num_iterations                                                         500
# max_depth                                                                5
# num_leaves                                                               6
# min_data_in_leaf                                                        94
# min_sum_hessian_in_leaf                                               0.01
# min_gain_to_split                                                      0.0
# bagging_fraction                                                  0.572203
# feature_fraction_bynode                                           0.932327
# bagging_freq                                                             1
# verbosity                                                               -1
# learning_rate                                                         0.02
# objective                                                       regression
#
#                         Access_to_Electricity LE_at_birth
# boosting                                 gbdt        gbdt
# data_sample_strategy                  bagging     bagging
# num_iterations                            500         500
# max_depth                                   5           5
# num_leaves                                 16          15
# min_data_in_leaf                           17           4
# min_sum_hessian_in_leaf                  0.01        0.01
# min_gain_to_split                         0.0         0.0
# bagging_fraction                     0.537392    0.809136
# feature_fraction_bynode              0.643879    0.650828
# bagging_freq                                1           1
# verbosity                                  -1          -1
# learning_rate                            0.02        0.02
# objective                          regression  regression

# %%
kernel.mice(30,variable_parameters=optimal_params)
imputed_data = kernel.complete_data(0)

imputed_data['Country'] = data['Country']
imputed_data['Year'] = data['Year']

imputed_data.to_csv('Healthcare_Imputation.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

original_data = pd.read_csv("Quality_of_Life_final.csv")

original_data_clean = original_data.drop(['Country', 'Year'], axis=1)
imputed_data_clean = imputed_data.drop(['Country', 'Year'], axis=1)

def plot_distributions(original, imputed, column_name):
    plt.figure(figsize=(10, 6))

    sns.kdeplot(original.dropna(), label="Original (Non-Missing)", color='blue', shade=True)
    missing_indices = original[original.isna()].index
    sns.kdeplot(imputed.loc[missing_indices], label="Imputed", color='red', shade=True)
    
    plt.title(f'Distributional Comparison: {column_name}')
    plt.legend()
    plt.show()


for column in original_data_clean.columns:
    plot_distributions(original_data_clean[column], imputed_data_clean[column], column)
# Out:
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\602279902.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.

# %%
from sklearn.preprocessing import StandardScaler
import scipy.stats as stats
from factor_analyzer.factor_analyzer import calculate_kmo

df = pd.read_csv("Healthcare_imputation.csv")

df= df.interpolate(method='linear', limit_direction='forward', axis=0)

df_numeric = df.drop(columns=['Country', 'Year'])

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_numeric)

kmo_all,kmo_model=calculate_kmo(df_scaled)
kmo_model
# Out:
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_22584\183061858.py:7: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
# 0.8867331471520873

# %% [markdown]
# For comparision metrics, we will use the mean value in place of the NaN values and then compare the two datasets, from the mean imputed data set we will delete some values at random and then use these models only to predict those values and then calculate the scores for comparision and then judge these models.
