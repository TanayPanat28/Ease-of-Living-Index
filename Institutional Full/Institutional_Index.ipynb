# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Rule of Law 1996-2022.csv')

# %%
df.columns = [col.split(' ')[0] if 'YR' in col else col for col in df.columns]

# %%
df.columns = [col.split(' ')[0] if 'YR' in col else col for col in df.columns]
available_years = [col for col in df.columns if col.isdigit()]
series_of_interest = [
    'Control of Corruption: Estimate',
    'Government Effectiveness: Estimate',
    'Political Stability and Absence of Violence/Terrorism: Estimate',
    'Regulatory Quality: Estimate',
    'Rule of Law: Estimate',
    'Voice and Accountability: Estimate'
]

melted_dfs = {}

for series in series_of_interest:

    df_filtered = df[df['Series Name'] == series]
    
    melted = pd.melt(df_filtered, 
                     id_vars=['Country Name'], 
                     value_vars=available_years, 
                     var_name='Year', 
                     value_name=series)
    
    melted = melted.dropna(subset=[series])
    
    melted['Year'] = melted['Year'].astype(int)
    
    melted_dfs[series] = melted


merged_df = melted_dfs[series_of_interest[0]]

for series in series_of_interest[1:]:
    merged_df = pd.merge(merged_df, melted_dfs[series], on=['Country Name', 'Year'], how='outer')

merged_df.reset_index(drop=True, inplace=True)
merged_df.to_csv('Final_Merged_Series_Data.csv', index=False)

merged_df.head()
# Out:
#      Country Name  Year Control of Corruption: Estimate  \
# 0     Afghanistan  1996                    -1.291704774
# 1         Albania  1996                    -0.893903494
# 2         Algeria  1996                     -0.56674093
# 3  American Samoa  1996                              ..
# 4         Andorra  1996                     1.318143249
#
#   Government Effectiveness: Estimate  \
# 0                       -2.175166607
# 1                       -0.688587904
# 2                       -1.088766456
# 3                                 ..
# 4                        1.414037704
#
#   Political Stability and Absence of Violence/Terrorism: Estimate  \
# 0                                       -2.417309523
# 1                                       -0.336625129
# 2                                       -1.783310533
# 3                                                 ..
# 4                                        1.169522166
#
#   Regulatory Quality: Estimate Rule of Law: Estimate  \
# 0                 -2.090330362          -1.788075447
# 1                 -0.474401653            -0.6844818
# 2                 -0.907437265          -1.218194842
# 3                           ..                    ..
# 4                  1.266439795           1.158362508
#
#   Voice and Accountability: Estimate
# 0                        -1.90854013
# 1                       -0.648297846
# 2                       -1.166290164
# 3                                 ..
# 4                        1.563216686
